# %% [markdown]
# <a href="https://colab.research.google.com/github/Chompybits/Homework-3/blob/main/%D0%9433_%D0%9F%D0%B8%D1%82%D0%BE%D0%BD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Для начала попробуем просто открыть файл и проверить что в нем есть.

# %%
with open('purchase_log.txt', 'r', encoding='utf-8') as file:
  lines = file.readlines()
  for line in lines:
        print(line.strip())

# %% [markdown]
# Задание 1
# Переведите содержимое файла purchase_log.txt в словарь purchases вида:
# {'1840e0b9d4': 'Продукты', ...}

# %%
purchases={}

with open('purchase_log.txt', 'r', encoding='utf-8') as file: #берем кодировку utf-8 что бы ру язык не глючил.
    next(file) # Пропустим первую строку
    for line in file: # Разбиваем строку на список слов
        words = line.strip('{}').split()
        user_id = words[1].strip('{,"}')
        category = words[3].strip('{,"}') # так и не понял почему пришлось чистить каждую строку, но в итоге удалось.
        #выделили по заданию второе и четвертое слово из каждой строки. Осталось добавить их в словарь
        purchases[user_id] = category


print(purchases)
# Out:
# {'Продукты': '1840e0b9d4', '4e4f90fcfb': 'Электроника', 'afea8d72fc': 'Электроника', '373a6055fe': 'Бытовая', '9b2ab046f3': 'Электроника', '9f39d307c3': 'Электроника', '44edeffc91': 'Продукты', '704474fa2d': 'Продукты', '1de31be403': 'Бытовая', 'b71f36a5e4': 'Продукты', '79843a685a': 'Продукты', 'ff68cee0d6': 'Бытовая', 'e8447c40e2': 'Досуг', '98d290be27': 'Электроника', 'fa0079a5a8': 'Досуг', '22d2f03a17': 'Досуг', '3f8e1ccd3f': 'Электроника', '81a9988b83': 'Электроника', '65f44a2eb7': 'Досуг', '5f8fbb0149': 'Бытовая', '3ecff691fd': 'Электроника', 'dd0e912251': 'Электроника', '9250593d55': 'Электроника', '37c4e090e4': 'Электроника', '22fa3ea76f': 'Электроника', '73b876b237': 'Электроника', 'f983a69d67': 'Товары', '4ea17212f8': 'Продукты', 'c6de96a5e2': 'Товары', 'd8e3bcee53': 'Продукты', '680aa815f9': 'Продукты', '4a92a68cf9': 'Электроника', '905e60cb52': 'Бытовая', '393bcfb298': 'Продукты', '06d450cc57': 'Электроника', 'b60ce22f17': 'Электроника', '6f159c4c2e': 'Товары', '564202f6b
# ...

# %% [markdown]
# Задание 2
#  Для каждого user_id в файле visit_log.csv определите третий столбец с
#  категорией покупки. Если покупка была, сам файл visit_log.csv изменять не
#  надо.
#  Запишите в файл funnel.csv визиты из файла visit_log.csv, в которых были
#  покупки с указанием категории.
#  Учтите условия для данных:
#  ● содержимое purchase_log.txt помещается в оперативную память
#  компьютера;
#  ● содержимое visit_log.csv — нет, используйте только построчную
#  обработку этого файла

# %%
purchases={}
#подготовим словарь как в задании 1
with open('purchase_log.txt', 'r', encoding='utf-8') as file: #берем кодировку utf-8 что бы ру язык не глючил.
    next(file) # Пропустим первую строку
    for line in file: # Разбиваем строку на список слов
        words = line.strip('{}').split()
        user_id = words[1].strip('{,"}')
        category = words[3].strip('{,"}') # так и не понял почему пришлось чистить каждую строку, но в итоге удалось.
        #выделили по заданию второе и четвертое слово из каждой строки. Осталось добавить их в словарь
        purchases[user_id] = category

with open('visit_log.csv', 'r', encoding='utf-8') as visit_file:
    with open('funnel.csv', 'w', encoding='utf-8') as funnel_file:

        header = visit_file.readline().strip()
        funnel_file.write(f"{header},category\n") #считаем заголовок из визитов и запишем в фаннел.

        # Поочереди обработаем каждую линию фаила visit_log и выпишем покупки с указаниями категорий убрав лишние символы.
        for line in visit_file:
            parts = line.strip().split(',')
            if len(parts) > 0: # Уберем пустые строки
                user_id = parts[0] # Примем то что user id расположен в первой колонке и будем это использовать

                # ищем категорию user_id через гет, если она есть то пишем ее.
                category = purchases.get(user_id)
                if category:
                    funnel_file.write(f"{line.strip()},{category}\n")

import pandas as pd
data = pd.read_csv('funnel.csv')
print(data)
# Out:
#           user_id   source       category
# 0      4e4f90fcfb  context    Электроника
# 1      afea8d72fc    other    Электроника
# 2      2824221f38    email       Продукты
# 3      373a6055fe    other        Бытовая
# 4      9b2ab046f3    other    Электроника
# ...           ...      ...            ...
# 13736  cb2da172f8    other  Строительство
# 13737  047fbda813    other        Бытовая
# 13738  cf797f912d    other        Бытовая
# 13739  9ff57c335f  context         Товары
# 13740  bdc8054507    other    Электроника
#
# [13741 rows x 3 columns]
